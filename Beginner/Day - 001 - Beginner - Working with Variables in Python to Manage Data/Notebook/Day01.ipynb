# %% [markdown]
# # Band Name Generator Project

# %%
print("Welcome to the Band Name Generator.")
city = input("Which city did you grow up in?\n")
pet = input("What is the name of a pet?\n")
print("Your band name could be " + city + " " + pet)
# Out:
# Welcome to the Band Name Generator.
# Your band name could be Jorges Kika

# %% [markdown]
# # Debugging Practice

# %%
print("Notes from Day 1")
print("The print statement is used to output strings")
print("Strings are strings of characters")
print("String Concatenation is done with the + sign")
print("New lines can be created with a \ and the letter n")
# Out:
# Notes from Day 1
# The print statement is used to output strings
# Strings are strings of characters
# String Concatenation is done with the + sign
# New lines can be created with a \ and the letter n
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\igorn\AppData\Local\Temp\ipykernel_9244\2768887504.py:5: SyntaxWarning: invalid escape sequence '\ '
#   print("New lines can be created with a \ and the letter n")

# %% [markdown]
# # Inputs
# * You can concatenate strings using the + operator, for example: print("Hello " + "!").
# * To get user input, you can use: input("What is your name?").

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# Hello Galaxy!

# %% [markdown]
# # Printing
# * print( ) = Console's Print
# * to get strings use print("string")

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # String Manipulation
# * "\n" is a newline character. It moves the cursor to the next line.

# %%
# 1.
print("Hello world!\nHello world!\nHello world!")
# 2.
print("Hello" + " " + "Angela")
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello Angela

# %% [markdown]
# # Variable Naming
# * nameVariable = valuorVariable
# * len() = **Length of an variable or value**

# %%
name = "Angela"
length = len(name)
print(length)
# Out:
# 6

# %% [markdown]
# # Variables

# %%
#1.
print(len(input("What is your name?")))

#2.
username = input("What is your name?")
length = len(username)
print(length)
# Out:
# 7
# 6

# %% [markdown]
# # VariableEx

# %%
glass1 = "milk"
glass2 = "juice"

glassAux = glass1
glass1 = glass2
glass2 = glassAux
